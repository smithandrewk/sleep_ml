# %%
import numpy as np
import matplotlib.pyplot as plt
from lib.utils import load_raw_list
import torch
from torch.nn.functional import relu,one_hot
from torch.utils.data import DataLoader
from torch.utils.data import TensorDataset
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
X,y = load_raw_list([20])
X = X.flatten()

# %%
y = one_hot(y,num_classes=3).reshape(-1,3).float()
X = X.reshape(-1,1,45000)
dataset = TensorDataset(X,y)
dataloader = DataLoader(dataset, batch_size=128, shuffle=True)

# %%
from torch import nn
class CNNLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(CNNLSTM, self).__init__()
        
        self.conv1 = nn.Conv1d(input_size, 16, kernel_size=3, padding=1)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool1d(kernel_size=2)
        self.lstm1 = nn.LSTM(16, hidden_size, batch_first=True)
        self.fc1 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.pool1(x)
        x = x.permute(0, 2, 1)
        x, _ = self.lstm1(x)
        x = x[:, -1, :]
        x = self.fc1(x)
        return x

# %%
model = CNNLSTM(1,2,3).cuda()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())
train_losses= []

# %%
for epoch in range(10):
    training_loss = 0
    model.train()
    for (X,y) in dataloader:
        X,y = X.cuda(), y.cuda()
        logits = model(X)
        loss = criterion(logits,y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        training_loss += loss.item()
    train_losses.append(training_loss/len(dataloader))
    print(f'Epoch {epoch} Train: {training_loss/len(dataloader)}')
# Out:
# Epoch 0 Train: 0.8634039238095284
# Epoch 1 Train: 0.8587204366922379
# Epoch 2 Train: 0.8619078546762466
# Epoch 3 Train: 0.8548403233289719
# Epoch 4 Train: 0.858273096382618
# Epoch 5 Train: 0.8629942089319229
# Epoch 6 Train: 0.8627294152975082
# Epoch 7 Train: 0.862028457224369
# Epoch 8 Train: 0.8579933345317841
# Epoch 9 Train: 0.8498092144727707

# %%
y_pred_logits = model(X)
sm = nn.Softmax(dim=1)
y_pred = sm(y_pred_logits).argmax(axis=1)
cm = ConfusionMatrixDisplay(confusion_matrix(y.argmax(axis=1).cpu().squeeze().cpu(),y_pred.cpu(),normalize='true'),display_labels=['P','S','W'])
cm.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/andrew/sleep_ml/cnn_LSTM.ipynb Cell 6 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/home/andrew/sleep_ml/cnn_LSTM.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> y_pred = sm(y_pred_logits).argmax(axis=1)
#       <a href='vscode-notebook-cell:/home/andrew/sleep_ml/cnn_LSTM.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> cm = ConfusionMatrixDisplay(confusion_matrix(y.argmax(axis=1).cpu().squeeze().cpu(),y_pred.cpu(),normalize='true'),display_labels=['P','S','W'])
# ----> <a href='vscode-notebook-cell:/home/andrew/sleep_ml/cnn_LSTM.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> cm.plot()
#
# File ~/.local/lib/python3.10/site-packages/sklearn/metrics/_plot/confusion_matrix.py:172, in ConfusionMatrixDisplay.plot(self, include_values, cmap, xticks_rotation, values_format, ax, colorbar, im_kw)
#     170 if colorbar:
#     171     fig.colorbar(self.im_, ax=ax)
# --> 172 ax.set(
#     173     xticks=np.arange(n_classes),
#     174     yticks=np.arange(n_classes),
#     175     xticklabels=display_labels,
#     176     yticklabels=display_labels,
#     177     ylabel="True label",
#     178     xlabel="Predicted label",
#     179 )
#     181 ax.set_ylim((n_classes - 0.5, -0.5))
#     182 plt.setp(ax.get_xticklabels(), rotation=xticks_rotation)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:117, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     109 if not hasattr(cls.set, '_autogenerated_signature'):
#     110     # Don't overwrite cls.set if the subclass or one of its parents
#     111     # has defined a set method set itself.
#     112     # If there was no explicit definition, cls.set is inherited from
#     113     # the hierarchy of auto-generated set methods, which hold the
#     114     # flag _autogenerated_signature.
#     115     return
# --> 117 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     118 cls.set.__name__ = "set"
#     119 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:1167, in Artist.set(self, **kwargs)
#    1162 def set(self, **kwargs):
#    1163     # docstring and signature are auto-generated via
#    1164     # Artist._update_set_signature_and_docstring() at the end of the
#    1165     # module.
#    1166     kwargs = cbook.normalize_kwargs(kwargs, self)
# -> 1167     return self.update(kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/artist.py:1069, in Artist.update(self, props)
#    1066             if not callable(func):
#    1067                 raise AttributeError(f"{type(self).__name__!r} object "
#    1068                                      f"has no property {k!r}")
# -> 1069             ret.append(func(v))
#    1070 if ret:
#    1071     self.pchanged()
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_base.py:75, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      74 def wrapper(self, *args, **kwargs):
# ---> 75     return get_method(self)(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:1798, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796 if fontdict is not None:
#    1797     kwargs.update(fontdict)
# -> 1798 return self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axis.py:1720, in Axis.set_ticklabels(self, ticklabels, minor, **kwargs)
#    1716 if isinstance(locator, mticker.FixedLocator):
#    1717     # Passing [] as a list of ticklabels is often used as a way to
#    1718     # remove all tick labels, so only error for > 0 ticklabels
#    1719     if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
# -> 1720         raise ValueError(
#    1721             "The number of FixedLocator locations"
#    1722             f" ({len(locator.locs)}), usually from a call to"
#    1723             " set_ticks, does not match"
#    1724             f" the number of ticklabels ({len(ticklabels)}).")
#    1725     tickd = {loc: lab for loc, lab in zip(locator.locs, ticklabels)}
#    1726     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (2), usually from a call to set_ticks, does not match the number of ticklabels (3).

# %%
plt.plot(train_losses)
